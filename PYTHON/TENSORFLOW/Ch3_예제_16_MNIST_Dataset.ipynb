# %% [markdown]
# <a href="https://colab.research.google.com/github/KwonYN/TIL/blob/master/PYTHON/TENSORFLOW/Ch3_%EC%98%88%EC%A0%9C_16_MNIST_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter3-5. Deep Learning 기초 : Multi Layer Perceptron (MLP)

# %% [markdown]
# >## [예제3-16] MNIST Dataset

# %% [markdown]
# >### Load modules

# %%
# %tensorflow_version 1.x

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

print("Module Loaded.")
print("NumPy Version :{}".format(np.__version__))
print("TensorFlow Version :{}".format(tf.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# Module Loaded.
# NumPy Version :1.17.4
# TensorFlow Version :1.15.0
# Matplotlib Version :3.1.1

# %% [markdown]
# >### Load Module : MNIST 관련

# %%
# from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# > ### Load MNIST data

# %%
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# > ### Type, Shape of Data

# %%
print("[train_data]")
print("Type : {}".format(type(train_data)))
print("Shape : {}".format(train_data.shape))  # about this?: 28pixel * 28pixel // grey scale // 1 pixel을 0(빛 없음 == 검정색) ~ 255(밝음 == 흰색)으로 표현!
                                              # 그런데 이 28 * 28짜리 그림이 60,000개 있다는 것!
#print(train_data)

print()

print("[test_data]")
print("Type : {}".format(type(test_data)))
print("Shape : {}".format(test_data.shape)) #
#print(test_data)
# Out:
# [train_data]
# Type : <class 'numpy.ndarray'>
# Shape : (60000, 28, 28)
#
# [test_data]
# Type : <class 'numpy.ndarray'>
# Shape : (10000, 28, 28)

# %% [markdown]
# > ### Type, Shape of Label

# %%
print("[train_labels]")
print("Type : {}".format(type(train_labels)))
print("Shape : {}".format(train_labels.shape))  # 60,000개의 train_data에 대한 답(각각) - scalar 값으로(0 ~ 9)

print()

print("[test_labels]")
print("Type : {}".format(type(test_labels)))
print("Shape : {}".format(test_labels.shape))
# Out:
# [train_labels]
# Type : <class 'numpy.ndarray'>
# Shape : (60000,)
#
# [test_labels]
# Type : <class 'numpy.ndarray'>
# Shape : (10000,)

# %% [markdown]
# >### Train data, labels

# %%
#print(train_data.shape[0])  # 60,000이겠지?
idx_show = np.arange(0, train_data.shape[0])  # train_data의 개수만큼의 배열을 만들고
np.random.shuffle(idx_show)                   # 다 섞어줌 ㅋㅋㅋ
idx_show = idx_show[0:10]                     # idx 0 ~ 9까지 슬라이싱 했다는 것은, 위의 셔플 때문에 랜덤하게 열 개 고른 것과 같겠지?

fig_train, ax_train = plt.subplots(2,5,figsize=(16, 7))
fig_train.suptitle("Train Data")
for idx in range(10):
    ax_train[idx//5][idx%5].imshow(train_data[idx_show[idx]],cmap="binary")
    ax_train[idx//5][idx%5].set_title("train_data[{}] (label : {})".format(idx_show[idx], train_labels[idx_show[idx]]))

# %% [markdown]
# >### Test data, labels

# %%
idx_show = np.arange(0, test_data.shape[0])
np.random.shuffle(idx_show)
idx_show = idx_show[0:10]
fig_test, ax_test = plt.subplots(2,5,figsize=(16, 7))
fig_test.suptitle("Test Data")
for idx in range(10):
    ax_test[idx//5][idx%5].imshow(test_data[idx_show[idx]],cmap="binary")
    ax_test[idx//5][idx%5].set_title("test_data[{}] (label : {})".format(idx_show[idx], test_labels[idx_show[idx]]))
